# %% [markdown]
# # Jupytertheme

# %%
pip install jupyterthemes

# %%
jt -l

# %%
jt -t onedork -fs 115 -nfs 125 -tfs 115 -dfs 115 -ofs 115 -cursc r -cellw 80% -lineh 115 -altmd  -kl -T -N

# %% [markdown]
# # extension

# %%
pip install jupyter_contrib_nbextensions
# Out:
# Collecting jupyter_contrib_nbextensions
#   Using cached jupyter_contrib_nbextensions-0.5.1-py2.py3-none-any.whl (20.9 MB)
# Requirement already satisfied: ipython-genutils in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: nbconvert>=4.2 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (6.0.7)
# Processing c:\users\doomoolmori\appdata\local\pip\cache\wheels\4d\ba\f4\b8c0941055519ebc0f27e85bfe2bb223f1a59a3b8bfc5c7515\jupyter_latex_envs-1.4.6-py2.py3-none-any.whl
# Requirement already satisfied: lxml in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (4.6.1)
# Requirement already satisfied: notebook>=4.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (6.1.4)
# Collecting jupyter-highlight-selected-word>=0.1.1
#   Using cached jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting jupyter-contrib-core>=0.3.3
#   Using cached jupyter_contrib_core-0.3.3-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: traitlets>=4.1 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (5.0.5)
# Processing c:\users\doomoolmori\appdata\local\pip\cache\wheels\e3\3a\b3\a709b437602c3807f079f0c35ccba3e1adf9af6f2e6b0ebfea\jupyter_nbextensions_configurator-0.4.1-py2.py3-none-any.whl
# Requirement already satisfied: pyyaml in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (5.3.1)
# Requirement already satisfied: tornado in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (6.0.4)
# Requirement already satisfied: jupyter-core in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (4.6.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.3)
# Requirement already satisfied: defusedxml in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.6.0)
# Requirement already satisfied: nbformat>=4.4 in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (5.0.8)
# Requirement already satisfied: testpath in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (1.4.3)
# Requirement already satisfied: bleach in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (3.2.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.7.2)
# Requirement already satisfied: jinja2>=2.4 in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.11.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.1.2)
# Requirement already satisfied: ipython in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (7.19.0)
# Requirement already satisfied: argon2-cffi in c:\users\doomoolmori\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (20.1.0)
# Requirement already satisfied: prometheus-client in c:\users\doomoolmori\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.8.0)
# Requirement already satisfied: ipykernel in c:\users\doomoolmori\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (5.3.4)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\doomoolmori\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (6.1.7)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\doomoolmori\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.9.1)
# Requirement already satisfied: Send2Trash in c:\users\doomoolmori\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\doomoolmori\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (19.0.2)
# Requirement already satisfied: setuptools in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (50.3.1.post20201107)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-core->jupyter_contrib_nbextensions) (227)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (3.2.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.15.0)
# Requirement already satisfied: webencodings in c:\users\doomoolmori\anaconda3\lib\site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: packaging in c:\users\doomoolmori\anaconda3\lib\site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (20.4)
# Requirement already satisfied: nest-asyncio in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.4.2)
# Requirement already satisfied: async-generator in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.10)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.1.1)
# Requirement already satisfied: decorator in c:\users\doomoolmori\anaconda3\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (4.4.2)
# Requirement already satisfied: jedi>=0.10 in c:\users\doomoolmori\anaconda3\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\doomoolmori\anaconda3\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (3.0.8)
# Requirement already satisfied: pickleshare in c:\users\doomoolmori\anaconda3\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: backcall in c:\users\doomoolmori\anaconda3\lib\site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (1.14.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.0->jupyter_contrib_nbextensions) (2.8.1)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\doomoolmori\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.0->jupyter_contrib_nbextensions) (0.5.7)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (20.3.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\doomoolmori\anaconda3\lib\site-packages (from packaging->bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (2.4.7)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jedi>=0.10->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\doomoolmori\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: pycparser in c:\users\doomoolmori\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (2.20)
# Installing collected packages: jupyter-latex-envs, jupyter-highlight-selected-word, jupyter-contrib-core, jupyter-nbextensions-configurator, jupyter-contrib-nbextensions
# Successfully installed jupyter-contrib-core-0.3.3 jupyter-contrib-nbextensions-0.5.1 jupyter-highlight-selected-word-0.2.0 jupyter-latex-envs-1.4.6 jupyter-nbextensions-configurator-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter-book
# Out:
# Collecting jupyter-book
#   Using cached jupyter_book-0.10.0-py3-none-any.whl (47 kB)
# Collecting sphinx-book-theme>=0.0.39
#   Using cached sphinx_book_theme-0.0.39-py3-none-any.whl (86 kB)
# Requirement already satisfied: nbformat in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-book) (5.0.8)
# Requirement already satisfied: pyyaml in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-book) (5.3.1)
# Collecting nested-lookup~=0.2.21
#   Using cached nested-lookup-0.2.22.tar.gz (10 kB)
# Requirement already satisfied: click in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-book) (7.1.2)
# Collecting sphinxcontrib-bibtex~=2.1.0
#   Using cached sphinxcontrib_bibtex-2.1.4-py3-none-any.whl (17 kB)
# Collecting sphinx-comments
#   Using cached sphinx_comments-0.0.3-py3-none-any.whl (4.6 kB)
# Collecting sphinx-copybutton
#   Using cached sphinx_copybutton-0.3.1-py3-none-any.whl (10 kB)
# Collecting sphinx-togglebutton
#   Using cached sphinx_togglebutton-0.2.3-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: sphinx<4,>=2 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-book) (3.2.1)
# Collecting myst-nb~=0.11.1
#   Using cached myst_nb-0.11.1-py3-none-any.whl (36 kB)
# Collecting sphinx-thebe>=0.0.6
#   Using cached sphinx_thebe-0.0.8-py3-none-any.whl (7.4 kB)
# Collecting linkify-it-py~=1.0.1
#   Using cached linkify_it_py-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: setuptools in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-book) (50.3.1.post20201107)
# Requirement already satisfied: docutils>=0.15 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-book) (0.16)
# Collecting nbconvert<6
#   Using cached nbconvert-5.6.1-py2.py3-none-any.whl (455 kB)
# Collecting sphinx-panels~=0.5.2
#   Using cached sphinx_panels-0.5.2-py3-none-any.whl (87 kB)
# Requirement already satisfied: jsonschema in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-book) (3.2.0)
# Collecting jupytext~=1.8.0
#   Using cached jupytext-1.8.2-py3-none-any.whl (284 kB)
# Collecting pydata-sphinx-theme~=0.4.1
#   Using cached pydata_sphinx_theme-0.4.3-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: beautifulsoup4 in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx-book-theme>=0.0.39->jupyter-book) (4.9.3)
# Requirement already satisfied: ipython-genutils in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbformat->jupyter-book) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbformat->jupyter-book) (4.6.3)
# Requirement already satisfied: traitlets>=4.1 in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbformat->jupyter-book) (5.0.5)
# Requirement already satisfied: six in c:\users\doomoolmori\anaconda3\lib\site-packages (from nested-lookup~=0.2.21->jupyter-book) (1.15.0)
# Collecting pybtex>=0.20
#   Using cached pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
# Collecting pybtex-docutils>=0.2.2
#   Using cached pybtex_docutils-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: wheel in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx-togglebutton->jupyter-book) (0.35.1)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (1.0.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (1.1.4)
# Requirement already satisfied: babel>=1.3 in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (2.8.1)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (1.0.2)
# Requirement already satisfied: snowballstemmer>=1.1 in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (2.0.0)
# Requirement already satisfied: packaging in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (20.4)
# Requirement already satisfied: colorama>=0.3.5; sys_platform == "win32" in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (0.4.4)
# Requirement already satisfied: requests>=2.5.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (2.24.0)
# Requirement already satisfied: imagesize in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (1.2.0)
# Requirement already satisfied: Jinja2>=2.3 in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (2.11.2)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (1.0.3)
# Requirement already satisfied: Pygments>=2.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (2.7.2)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (0.7.12)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp in c:\users\doomoolmori\anaconda3\lib\site-packages (from sphinx<4,>=2->jupyter-book) (1.0.3)
# Requirement already satisfied: ipython in c:\users\doomoolmori\anaconda3\lib\site-packages (from myst-nb~=0.11.1->jupyter-book) (7.19.0)
# Collecting jupyter-cache~=0.4.1
#   Using cached jupyter_cache-0.4.2-py3-none-any.whl (31 kB)
# Collecting myst-parser~=0.13.3
#   Using cached myst_parser-0.13.3-py3-none-any.whl (44 kB)
# Requirement already satisfied: importlib-metadata in c:\users\doomoolmori\anaconda3\lib\site-packages (from myst-nb~=0.11.1->jupyter-book) (2.0.0)
# Collecting jupyter-sphinx==0.3.1
#   Using cached jupyter_sphinx-0.3.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: ipywidgets<8,>=7.0.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from myst-nb~=0.11.1->jupyter-book) (7.5.1)
# Collecting uc-micro-py
#   Using cached uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: defusedxml in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert<6->jupyter-book) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert<6->jupyter-book) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert<6->jupyter-book) (1.4.3)
# Requirement already satisfied: testpath in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert<6->jupyter-book) (0.4.4)
# Requirement already satisfied: bleach in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert<6->jupyter-book) (3.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbconvert<6->jupyter-book) (0.8.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jsonschema->jupyter-book) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jsonschema->jupyter-book) (20.3.0)
# Collecting markdown-it-py~=0.6.0
#   Using cached markdown_it_py-0.6.2-py3-none-any.whl (81 kB)
# Requirement already satisfied: toml in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupytext~=1.8.0->jupyter-book) (0.10.1)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\doomoolmori\anaconda3\lib\site-packages (from beautifulsoup4->sphinx-book-theme>=0.0.39->jupyter-book) (2.0.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-core->nbformat->jupyter-book) (227)
# Collecting latexcodec>=1.0.4
#   Using cached latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pytz>=2015.7 in c:\users\doomoolmori\anaconda3\lib\site-packages (from babel>=1.3->sphinx<4,>=2->jupyter-book) (2020.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\doomoolmori\anaconda3\lib\site-packages (from packaging->sphinx<4,>=2->jupyter-book) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\doomoolmori\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx<4,>=2->jupyter-book) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\doomoolmori\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx<4,>=2->jupyter-book) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\doomoolmori\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx<4,>=2->jupyter-book) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\doomoolmori\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx<4,>=2->jupyter-book) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\doomoolmori\anaconda3\lib\site-packages (from Jinja2>=2.3->sphinx<4,>=2->jupyter-book) (1.1.1)
# Requirement already satisfied: decorator in c:\users\doomoolmori\anaconda3\lib\site-packages (from ipython->myst-nb~=0.11.1->jupyter-book) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from ipython->myst-nb~=0.11.1->jupyter-book) (3.0.8)
# Requirement already satisfied: backcall in c:\users\doomoolmori\anaconda3\lib\site-packages (from ipython->myst-nb~=0.11.1->jupyter-book) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\doomoolmori\anaconda3\lib\site-packages (from ipython->myst-nb~=0.11.1->jupyter-book) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in c:\users\doomoolmori\anaconda3\lib\site-packages (from ipython->myst-nb~=0.11.1->jupyter-book) (0.17.1)
# Collecting nbdime
#   Using cached nbdime-2.1.0-py2.py3-none-any.whl (5.0 MB)
# Requirement already satisfied: nbclient<0.6,>=0.2 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (0.5.1)
# Requirement already satisfied: sqlalchemy~=1.3.12 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (1.3.20)
# Collecting mdit-py-plugins~=0.2.4
#   Using cached mdit_py_plugins-0.2.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\doomoolmori\anaconda3\lib\site-packages (from importlib-metadata->myst-nb~=0.11.1->jupyter-book) (3.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\doomoolmori\anaconda3\lib\site-packages (from ipywidgets<8,>=7.0.0->myst-nb~=0.11.1->jupyter-book) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from ipywidgets<8,>=7.0.0->myst-nb~=0.11.1->jupyter-book) (3.5.1)
# Requirement already satisfied: webencodings in c:\users\doomoolmori\anaconda3\lib\site-packages (from bleach->nbconvert<6->jupyter-book) (0.5.1)
# Requirement already satisfied: wcwidth in c:\users\doomoolmori\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->myst-nb~=0.11.1->jupyter-book) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jedi>=0.10->ipython->myst-nb~=0.11.1->jupyter-book) (0.7.0)
# Requirement already satisfied: tornado in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbdime->jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (6.0.4)
# Collecting GitPython!=2.1.4,!=2.1.5,!=2.1.6
#   Using cached GitPython-3.1.13-py3-none-any.whl (159 kB)
# Requirement already satisfied: notebook in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbdime->jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (6.1.4)
# Requirement already satisfied: nest-asyncio in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbclient<0.6,>=0.2->jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (1.4.2)
# Requirement already satisfied: async-generator in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbclient<0.6,>=0.2->jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (1.10)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\doomoolmori\anaconda3\lib\site-packages (from nbclient<0.6,>=0.2->jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (6.1.7)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.5-py3-none-any.whl (63 kB)
# Requirement already satisfied: argon2-cffi in c:\users\doomoolmori\anaconda3\lib\site-packages (from notebook->nbdime->jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\doomoolmori\anaconda3\lib\site-packages (from notebook->nbdime->jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (0.9.1)
# Requirement already satisfied: prometheus-client in c:\users\doomoolmori\anaconda3\lib\site-packages (from notebook->nbdime->jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (0.8.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\doomoolmori\anaconda3\lib\site-packages (from notebook->nbdime->jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (19.0.2)
# Requirement already satisfied: Send2Trash in c:\users\doomoolmori\anaconda3\lib\site-packages (from notebook->nbdime->jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\doomoolmori\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6,>=0.2->jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (2.8.1)
# Collecting smmap<4,>=3.0.1
#   Using cached smmap-3.0.5-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\doomoolmori\anaconda3\lib\site-packages (from argon2-cffi->notebook->nbdime->jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (1.14.3)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\doomoolmori\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->nbdime->jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (0.5.7)
# Requirement already satisfied: pycparser in c:\users\doomoolmori\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook->nbdime->jupyter-cache~=0.4.1->myst-nb~=0.11.1->jupyter-book) (2.20)
# Building wheels for collected packages: nested-lookup
#   Building wheel for nested-lookup (setup.py): started
#   Building wheel for nested-lookup (setup.py): finished with status 'done'
#   Created wheel for nested-lookup: filename=nested_lookup-0.2.22-py3-none-any.whl size=7688 sha256=89f7d3feeab0c8bae669372c97f3f4a27b7df8bbc32c3603a9e90b668fcf56e4
#   Stored in directory: c:\users\doomoolmori\appdata\local\pip\cache\wheels\df\27\70\9718d662d1b80e9cf0e20e9872dfa65922f477c0526b615ada
# Successfully built nested-lookup
# Installing collected packages: pydata-sphinx-theme, sphinx-book-theme, nested-lookup, latexcodec, pybtex, pybtex-docutils, sphinxcontrib-bibtex, sphinx-comments, sphinx-copybutton, sphinx-togglebutton, smmap, gitdb, GitPython, nbdime, jupyter-cache, markdown-it-py, mdit-py-plugins, myst-parser, nbconvert, jupyter-sphinx, myst-nb, sphinx-thebe, uc-micro-py, linkify-it-py, sphinx-panels, jupytext, jupyter-book
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.0.7
#     Uninstalling nbconvert-6.0.7:
#       Successfully uninstalled nbconvert-6.0.7
# Successfully installed GitPython-3.1.13 gitdb-4.0.5 jupyter-book-0.10.0 jupyter-cache-0.4.2 jupyter-sphinx-0.3.1 jupytext-1.8.2 latexcodec-2.0.1 linkify-it-py-1.0.1 markdown-it-py-0.6.2 mdit-py-plugins-0.2.5 myst-nb-0.11.1 myst-parser-0.13.3 nbconvert-5.6.1 nbdime-2.1.0 nested-lookup-0.2.22 pybtex-0.24.0 pybtex-docutils-1.0.0 pydata-sphinx-theme-0.4.3 smmap-3.0.5 sphinx-book-theme-0.0.39 sphinx-comments-0.0.3 sphinx-copybutton-0.3.1 sphinx-panels-0.5.2 sphinx-thebe-0.0.8 sphinx-togglebutton-0.2.3 sphinxcontrib-bibtex-2.1.4 uc-micro-py-1.0.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# spyder 4.1.5 requires pyqt5<5.13; python_version >= "3", which is not installed.
# spyder 4.1.5 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
